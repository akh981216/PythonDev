# %% [markdown]
# #### 점프투파이썬
# ---
# 04장 연습문제

# %% [markdown]
# > Q1
# ``` py
#     주어진 자연수가 홀수인지 짝수인지 판별해 주는 함수(is_odd)를 작성해 보자.
# ```

# %%
def is_odd(number):
    if number % 2 == 1:
        return True
    else:
        return False

# n =13
# print(is_odd(n))

n =6
if is_odd(n):
    print(f"{n}은(는) 홀수입니다.")
else:
    print(f"{n}은(는) 짝수입니다.")
# Out:
# 6은(는) 짝수입니다.

# %% [markdown]
# > Q2
# ``` py
#     입력으로 들어오는 모든 수의 평균 값을 계산해 주는 함수를 작성해 보자.
#     (단 입력으로 들어오는 수의 개수는 정해져 있지 않다.)
#     ※ 평균 값을 구할 때 len 함수를 사용해 보자.
# ```

# %%
def get_avg(args):
    return sum(args) / len(args)

data_in = 10.3,12.1,30,3.14,10

print("평균 = ",round(get_avg(data_in),2))
# Out:
# 평균 =  13.11

# %% [markdown]
# > Q3
# ``` py
#     다음은 두 개의 숫자를 입력받아 더하여 돌려주는 프로그램이다.
#
#     input1 = input("첫번째 숫자를 입력하세요:")
#     input2 = input("두번째 숫자를 입력하세요:")
#
#     total = input1 + input2
#     print("두 수의 합은 %s 입니다" % total)
#     이 프로그램을 수행해 보자.
#
#     첫번째 숫자를 입력하세요:3
#     두번째 숫자를 입력하세요:6
#     두 수의 합은 36 입니다
#     3과 6을 입력했을 때 9가 아닌 36이라는 결괏값을 돌려주었다.
#     이 프로그램의 오류를 수정해 보자.
# ```

# %% [markdown]
# > Q4
# ``` py
#     다음 중 출력 결과가 다른 것 한 개를 골라 보자.
#
#     1. print("you" "need" "python")
#     2. print("you"+"need"+"python")
#     3. print("you", "need", "python")
#     4. print("".join(["you", "need", "python"]))
# ```

# %%
# print("you" "need" "python")
# print("you"+"need"+"python")
# print("you", "need", "python")
# print("".join(["you", "need", "python"]))

text = ":".join(["you","need", "python"])
print(text)
# text="you: need:python" 문자열 상수

new_text = text.replace(':','-') # "you-need-python"
print(new_text)

splist = new_text.split('-') # split는 list를 return한다.
print(splist)
print(type(splist))
splist[2]
# Out:
# you:need:python
# you-need-python
# ['you', 'need', 'python']
# <class 'list'>
# 'python'

# %% [markdown]
# > Q5
# ``` py
#     다음은 "test.txt"라는 파일에 "Life is too short" 문자열을 저장한 후
#     다시 그 파일을 읽어서 출력하는 프로그램이다.
#
#     f1 = open("test.txt", 'w')
#     f1.write("Life is too short")
#
#     f2 = open("test.txt", 'r')
#     print(f2.read())
#     이 프로그램은 우리가 예상한 "Life is too short"라는 문장을 출력하지 않는다.
#     우리가 예상한 값을 출력할 수 있도록 프로그램을 수정해 보자.
# ```

# %%
f1 = open("test.txt",'w')
f1.write("Life is too short")
f1.close

f2 = open("test.txt",'r')
print(f2.read())
f2.close()
# Out:
# Life is too short

# %%
try:
    f1 = open("test.txt",'w')
    f1.write("Life is too short")
except Exception as ex:
    print(ex)
finally:
    f1.close()

f2 = open("test.txt",'r')
print(f2.read())
f2.close()
# Out:
# Life is too short

# %% [markdown]
# > Q6
# ``` py
#     사용자의 입력을 파일(test.txt)에 저장하는 프로그램을 작성해 보자.
#     (단 프로그램을 다시 실행하더라도 기존에 작성한 내용을 유지하고 새로 입력한 내용을 추가해야 한다.)
# ```

# %%
dt = input("메시지를 입력해 주세요: ")

#기존 파일에 추가 메시지 저장
with open("test.txt",'a', encoding ='utf-8') as fw:
    fw.write('\n'+dt)

with open("test.txt",'r', encoding='utf-8') as fr:
    print(fr.read())
# Out:
# Life is too short안녕하세요~
# 2라인
# 세번째 입력.....

# %% [markdown]
# > Q7
# ``` py
#     다음과 같은 내용을 지닌 파일 test.txt가 있다.
#     이 파일의 내용 중 "java"라는 문자열을 "python"으로 바꾸어서 저장해 보자.
#
#     Life is too short
#     you need java
#     ※ replace 함수를 사용해 보자.
# ```

# %%
with open("test.txt",'rt', encoding='utf-8') as fr:
    data = fr.read().replace("java", "python")

with open("test.txt",'wt',encoding='utf-8') as fw:
    fw.write(data)

# %% [markdown]
# #### 바이너리 파일 다루기
# ---

# %%
from urllib import request 

target = request.urlopen("data:image/jpeg;base64,...")
bin_file = target.read()
print(bin_file)

with open("..\\source\\what.jpg")

# print(target)
# print(type(target))
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\n\x07\x08\x16\x16\x15\x18\x16\x16\x15\x19\x18\x18\x1a\x1a\x1a\x1c\x1a\x1a\x18\x1c\x18\x1a\x1a\x1a\x1a\x1e\x18\x1a\x1e\x1e\x1a\x1c\x1a\x1c!.%\x1c\x1e+\x1f\x18\x1a\'8&+/1555\x1a$;@;4?.451\x01\x0c\x0c\x0c\x10\x0f\x10\x1c\x12\x12\x1e4!$$44444444444444411441444414441444444444444144444444\xff\xc0\x00\x11\x08\x00\xe1\x00\xe1\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x02\x04\x05\x06\x01\x07\xff\xc4\x00A\x10\x00\x01\x03\x02\x03\x04\x08\x03\x05\x06\x06\x03\x01\x01\x00\x00\x01\x00\x02\x11\x03!\x04\x121\x05AQa\x06"q\x81\x91\xa1\xb1\xf02\xc1\xd1\x13BR\xe1\xf1\x14br\x82\x92\xb2\x1534\xa2\xc2\xd2#Ss\xb3\x07\xff\xc4\x00\x18\x01\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x00\x04\xff\xc4\x00!\x11\x01\x01\x00\x02\x03\x01\x01\x00\x02\x03\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03!1A\x12Qq\x042B\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\x80\xd6\xa1\xb9H\r@\xa9\xaa\xa4\xa7\x86\x15\xc2\x13\xd3e=\xf0\xc9\xbb\'\x15R\x9dF\xfd\x9b\x88$\x81\x10\\\x1d\xba\xec\x1f\x14I\xe7\xc1oM"\t\xe2I6\xb5\xb7\xdbu\xf9\xaf?\xd9\xb8W\xd4x\x14\xceW\x8e\xb0t\xe5\xcb\x04A\x91y\x98\xd1m\xf6~\xd3\xc8\xf2\xccC\x98\xca\xd1\x16q-"FX\x9f\x84\x99\x90\'M\xc3E\x1eI\xb2d\xb1\xc6ai\x9a.\x0f\r\xcb\x90\xc4\x89\x87e\xb3\x87\x037\xb2\xf3\xdcV\x15\xcc7\xb8\xd08hLI\x03\xde\xe5\xe8;J\xa3\x03\x08p\x00\xb88\x02\xeb\x01\x02\xf7<\xb7sX\x01\x89vL\x86\xf2A3}4\x84\xb8nV\x88\xc1p5\x15\xad\xb2{Z\xac`\x9bF\xeam\x06.\xd2b\x87\xb4v\xc5:$\x89\xcc\xf1\xf7\x1b\x16\xfe\'\x1b7\xb3^Ir\xc8;\xabf\xb5p\xacV#\xa5\x8fq\x86\x0c\xa3\x83A\'\xbc\xef[\x1c\x00a\xc25\xd5\x0b\x8dCM\xf5*<<\x03L^\x00\x83\x96\xc2,f\xe4\xce\xaacw=\x1c&\x97\xacv\xd2\xe9!\xb0\xa4\xfc\xa0H1}".~#\xa9\x95[\xfe?\\}\xf2Gtx#\x07\xf3k\xd1XQ\x02\xf3\xfc7J`\x8c\xcd\xef\x16>_E\xa8\xd9\x9bY\x95\x04\xb5\xf3\xc4;^\xf4K\x966.\x9a\x94&S|\xa2\x04H\x87U\x97B\x95&\xb8Q^.\x9b\x12\xd7Jd\'$\x9et[v}64\x02\xe7h \x01 I:\t:\x0e%X\x1d\xa0ie\x9c\x8c\x0ek\x8el\xa6\x1b\x00E\xbb\x0c\xf7*\xdau2\x90@\x06/p\x0c\x1e7\xd0\xf3K\x13P\xbf\xe3\xeb^`\x81\x13\xd8\x9a\x1b\x1c\xb1\x91G\xb5\xb1\xce#+M\xa6n.\xe2o$s\x9d\xfcT\x8d\x95\x87\x01\x99\xcc\x97\xb8u\x89\xe4t\x1c\x02;\xf0\x8c.\xcd\x17\xf7\xe0\x8c\xd6\x80 #\xdf\xd6\xcf9q\xd4w/4\x92I\x14{\x045G\xae\xcb\xa9\xcfj\x13\xe9\xca\xe5\x97\xb7lBj\x9d\xb2\xb0,\xa8\xe3\xf6\x95[I\xa0L\x92\xd0]\'F\xe6?]\xca;\x98\x93Z\xa8\xcd\r\x07\xe1\xa8\x98\xa0\xf7\xbd\xef u\xac\xd1\x04\xc1\x07(\x92d\xf2\xe6\xa3m\x97\x17\xd5k\x0b\x03\\\x00\x19\x89=`n&@\x80/m\xd7U\x94\xe9\x93h3k\r{\x95\xae7\x0b\x89yi}7\x12\x1a\x1b\x9a\x05\xc0$\xdc\xcc\x17]&\xb5If\xaa\xa9\xee&\xc5\xc4\x81\xa4\x92@\xecBpRj\xd3-$\x10A\x1a\x83c\xe0\x85\xc944u\xa5\x1a\x9a\x18\n\x9f\xa48\xe2\xd6\x8aM0\\%\xe4k\x97sGm\xef\xc0sG.\xa3I\xbe\x9c\xda\xbbt\x92YD\xc0\xd1\xd5\x06\xa7\x88g\x01\xfb\xdb\xf7qY\xda\xc2\xdb\xa3\xde\xbcJ\xeep\xd1>\x1fT\xd6u\x9b\xcb\x8f\xea\xa2\xac\x9a\xf1\x15\xf5\xc8\xd0\xdb\xc1;\tQ\xddp\x04\xe7c\x9afm\x9a$\x81\xc6\xde\x04\xa9xl#\xea\xbcS\xa2\xc7>\xa3\xac\x1a\xcb\xbb\x89\xec\x1c\xcc\x00\xb9\xfe\x1dR\x9dGS\xaa\xc71\xcd\x8c\xccu\x88\xde\r\xf5\x07q\x1a\xadM\xd5\xe9\x1a\x90\x02\xd1<\xd1\\\xc6\x81\xc3\xb7\xeb(\xd8\x86\\\x91\xa4\xfb\xd500E\xacV\x95\xaa-ZPc\x8f\x9am\n\xcf\xa6\xe0\xe68\xb4\x8e\x1f0\xa59\x96\x83\xa7\xa1Q\xabQ;\xbd\x8e\xd4Y\xb0\xd8\xfd#.\x1dp\x04j\xe1\xa0\xe6F\xad\x1c\xf4\xbcoZ\xfc5p\xf0\x08\xde\xbc\x83\x07\x89,pp\xd3x\xe24\xd3}\xadu\xb4\xd88\xec\x8eh\x07\xa8\xfd5\x86?\x80\xe2\xd3\xb8n\xf1\x9d*9\xe3\xaf\x1a\x9cC\x0e\xb0`\xe8x\xf6 \x10\xad*m\x07>\x88fV\x98\x8b\x9d\xc3|\x0e7\x8dw\xaa\xd0\x13L\xbaF@\x1c\xd8\\r%D\xc5Ln\xc3)\xa0\xd2r~U\xc7\xb56\xc9`k\x89\xc9\xa14%)I:\xfc\x12Y\x84!q\xacE\x019\xac\\\x9bwH\x8bV\x98\xde\xa3\xb1\xbc\x14\xbcE"WiR[\x1b}5\xd4\x89\x1b\x11\xedmf\x17h\t\xf1\xca`x\xadeM\xa0\xc2!\xd9ZN\xe2f\x07\x13\xe1\xe4\xb1e\x90\x93\xc9\xb1\x9b\x8d\x0f>3\xc5=\x9f\xa4\xb2\x9bXm\xfamw]\x84\x18\xd7t\x8d\xdd\xb0g\xc5P\xb4IR^\xf7\xba\xc5\xc4\xf6\xa6\xb5\x90\x9b\x1 ...
